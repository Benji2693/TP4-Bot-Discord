# %% [markdown]
# TP 4 - Bot Discord

# %% [markdown]
# 1) Qu’est-ce qu’un bot ?
#
# Un bot n'est pas humain et effectue des taches qu'une personne pourrait faire de facon programmé.
# C'est donc une application programmée pour effectuer des taches automatiquement.

# %% [markdown]
# 2) Qu'est ce que le logging. À quoi servent les logs?
#
# Le logging est la journalisation. C'est donc la gestion des logs qui sont des journaux d'evenement qui est représenté par un fichier ou tout autre élement pouvant contenir l'historique des evenements.
# Les logs servent à suivre les evenements qui se produisent lors de l'exécution de certains logiciels. L'ajout d'appels de journalisation au code permet d'indiquer que certains événements se sont produits. Un événement est décrit par un message descriptif qui peut éventuellement contenir des données variables.
#
# ![image.png](attachment:139c03f7-d4ac-49ce-912b-4a10178baf43.png)
#
# Cet ecemple de logging permet de voir si nous somme bien rentré dans la fonction add. Dans la variable level on vas afficher plus ou moins de détails sur les élements et envoyé dans un fichier appart comme on peut voir sur la deuxième ligne.

# %% [markdown]
# EXPLICATION CODE :

# %% [markdown]
# J'ai réalisé mon bot en POO avec ma classe myBot. Elle contient le paramètre commands.Bot qui permet d'utiliser un objet Bot plus facile d'uilisation car avec seulement la commande command_prefix on pourra indiquer le caractère qui sera utilisé pour préfixer les commandes envoyées au bot.
#
# ![image.png](attachment:30031c70-6079-4d88-bfac-f250654d6f89.png)
#
# Comme on peut voir sur la photo précédente, on créer la classe myBot et on initialise le constructeur avec le def __init__ et on le surcharge de la command_prefix. De plus on créer la variable log associé a self pour permettre la journalisation avec la classe LogToi :
#
# ![image.png](attachment:7811ba32-c8ca-4491-a531-3743f93391f0.png)
#
# Cette classe permet de faire la journalisation. On initialise (comme pour la classe bot avec __init__ et on l'initialise avec le nom du fichier à modifier ou créer et comme vu plus haut avec le niveau d'affichage: level=logging.DEBUG
# J'expliquerais chaque fonction créé dans cette classe dès lors que nous l'utiliserons.

# %% [markdown]
# Ensuite on peut créer différentes fonctions permettant au bot de réagir avec l'utilisateur sur discord.
# Mais avant ca on vérifie si le bot est près comme sur la photo suivante:
#
# ![image.png](attachment:651ef8ce-0939-45c5-b998-114f270699c3.png)
#
# On utilise la fonction existante on_ready et on print sur notre terminal le nom du bot pour savoir qu'il s'est bien connecté. La journalisation est aussi faites avec la fonction logInfo créé dans la classe LogToi(). Elle permet donc d'écrire dans le fichier logging.log qui renvoie une sortie très détaillée pour faire le diagnostic.

# %% [markdown]
# La dernière fonction créé dans la classe myBot est la suivante:
#
# ![image.png](attachment:19e56a17-d23b-4753-86e3-cef87851204b.png)
#
# La fonction on_message() permet de voir qu'un utilisateur envoie un message (le bot aussi).
# La premiere journalisation est faites avec "print" mais on écrit sur un fichier donc on utilisera write. On ouvre le fichier log.txt avec la commmande open (on créer le fichier sinon) puis avec write on écrit dans le fichier l'auteur puis le message envoyé et on referme le fichier.
# La deuxieme méthode est celle la plus perfectionné car on utilise le log et la fonction sauvegarde de notre classe LogToi. La fonction sauvegarde vas faire comme pour la fonction logInfo, il va faire un diagnostic detaillé et enregistre le message avec le niveau DEBUG.

# %% [markdown]
# Enfin pour lancer le programme il nous faut la fonction main:
#
# ![image.png](attachment:a6c0a40d-1ddc-4905-b162-49d07c87c898.png)
#
# On instancie MyBot et on le lance avec run.
# os.getenv("TOKEN") permet de récupérer la variable "TOKEN" mis dans le fichier config. Avec l'import os et la fonction load_dotenv on pourra la récuperer.
# ![image.png](attachment:d45b0062-69b8-4d03-8fec-94dc95d7c0fc.png)
#
#
# A noter qu'il faudra que vous changiez le token mis dans le fichier config pour pouvoir lancer le BOT.
